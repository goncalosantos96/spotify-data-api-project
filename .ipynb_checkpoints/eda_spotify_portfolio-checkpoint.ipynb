# %%
from dotenv import load_dotenv
import os
import requests
import time
from typing import Dict, Optional

# %%
# Load the .env file
load_dotenv()
LIMIT = 50
OFFSET = 0

# %%
# Taken several artists to extract artists' genres
artists = [
    "Taylor Swift", "Lorde", "Coldplay", "The Weeknd", "Billie Eilish",
    "Queen", "Arctic Monkeys", "AC/DC", "Green Day", "Pink Floyd",
    "Metallica", "Iron Maiden", "Slayer", "Cannibal Corpse", "Mayhem",
    "Candlemass", "Nightwish", "Kendrick Lamar", "Travis Scott", "Nujabes",
    "SZA", "Erykah Badu", "James Brown", "Anitta", "Bob Marley",
    "The Specials", "Calvin Harris", "David Guetta", "Carl Cox", "Armin van Buuren",
    "Pendulum", "Skrillex", "Bonobo", "The Strokes", "Bon Iver",
    "Bob Dylan", "Johnny Cash", "B.B. King", "Miles Davis", "Ella Fitzgerald",
    "João Gilberto", "Caetano Veloso", "Cartola", "Zeca Pagodinho", "Marília Mendonça",
    "Ivete Sangalo", "Luiz Gonzaga", "Valete", "Diogo Piçarra", "Amália Rodrigues",
    "BTS", "Hikaru Utada", "Burna Boy", "Dino D'Santiago", "Cesária Évora",
    "Bad Bunny", "Paco de Lucía", "Frédéric Chopin", "Ludovico Einaudi", "Hans Zimmer",
    "Björk", "Jinsang", "Tame Impala", "Nirvana", "The Cure",
    "Frank Ocean", "Aretha Franklin", "Wet Bed Gang", "Central Cee", "Charli XCX",
    "The Midnight"
]

genres = []

# %%
# Url, payload and headers in order to get access token
SPOTIFY_URL_TOKEN = os.getenv('SPOTIFY_URL_TOKEN')
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# %%
def get_token(url_token: str, payload: dict, headers: dict):

    """
    Request a new access token to Spotify
    
    Return:
        str: succesfully return the access token
        None: if an error occured
    """
    try:
        response = requests.post(url_token, data=payload, headers=headers)
        response.raise_for_status()  # Throw an error if status >= 400

        data = response.json()
        access_token = data.get("access_token")

        if not access_token:
            print("Error: No token provided")
            print("Response:", data)
            return None

        return access_token

    except requests.exceptions.HTTPError as e:
        print(f"HTTP Error ({response.status_code}): {e}")
    except requests.exceptions.RequestException as e:
        print(f"Connection error: {e}")
    except Exception as e:
        print(f"Unexpected error: {e}")

    return None

# %%
payload = {

    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'grant_type': 'client_credentials'
}

headers = {

    'Content-type': 'application/x-www-form-urlencoded'
}

# %%
# Send my client id and client secret to request an access token
token = get_token(SPOTIFY_URL_TOKEN, payload, headers)

# %%
# header to send my authorization with access_token
headers = {
    'Authorization': f'Bearer {token}'
}

# %%
# Loop to get several genres to then get all artists inside that genres
for artist in artists:
    
    url = f'https://api.spotify.com/v1/search?q={artist}&type=artist'
    
    response = requests.get(url, headers = headers)

    records = response.json()
    
    genres.extend(records['artists']['items'][0]['genres'])

# %%
#List with unique genre values
unique_genres = set(genres)
genres_list = sorted(list(unique_genres))

# %%
print(genres_list)
# Out:
# ['afrobeat', 'afrobeats', 'afropiano', 'afropop', 'afroswing', 'alternative rock', 'anime', 'arrocha', 'art pop', 'art rock', 'axé', 'bebop', 'big band', 'black metal', 'blues', 'blues rock', 'bossa nova', 'brazilian funk', 'brazilian jazz', 'brazilian pop', 'chillwave', 'christmas', 'classic blues', 'classic country', 'classic rock', 'classic soul', 'classical', 'classical piano', 'cool jazz', 'country', 'country rock', 'dancehall', 'darkwave', 'death metal', 'deathcore', 'doom metal', 'downtempo', 'drill', 'drone metal', 'drum and bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'electronica', 'fado', 'flamenco', 'folk', 'folk metal', 'folk rock', 'forró', 'forró tradicional', 'free jazz', 'funk', 'funk carioca', 'funk pop', 'garage rock', 'glam rock', 'gothic metal', 'gothic rock', 'grindcore', 'groove metal', 'grunge', 'hard bop', 'hard rock', 'heavy metal', 'hip hop', 'house', 'hyperpop', 'indie', 'indie rock', 'j-pop', 'j-r&b', 'jazz', 'jazz blues', 'jazz fusion', 'jazz rap', 'k-pop', 'latin', 'latin jazz', 'lo-fi', 'lo-fi beats', 'lo-fi hip hop', 'metal', 'motown', 'mpb', 'neo soul', 'neo-psychedelic', 'neoclassical', 'new wave', 'nu jazz', 'outlaw country', 'pagode', 'pagode baiano', 'pop punk', 'portuguese hip hop', 'post-punk', 'power metal', 'progressive house', 'progressive rock', 'progressive trance', 'psychedelic rock', 'punk', 'r&b', 'ragga', 'rap', 'reggae', 'reggaeton', 'rock', 'rock and roll', 'rocksteady', 'roots reggae', 'roots rock', 'samba', 'sertanejo', 'sertanejo universitário', 'singer-songwriter', 'ska', 'ska punk', 'sludge metal', 'soul', 'soul blues', 'soundtrack', 'speed metal', 'stoner metal', 'swing music', 'symphonic metal', 'synthpop', 'synthwave', 'tech house', 'techno', 'thrash metal', 'trance', 'trap latino', 'trip hop', 'uk drill', 'uk grime', 'urbano latino', 'vaporwave', 'vocal jazz', 'west coast hip hop']

# %%
artists = []
artists_id = []

# %%
artists_metal = []
artists_metal_id = []
genre_metal = ['metal', 'rock']

# %%
metaleiro = set(artists_metal)
print(metaleiro)
# Out:
# {'Creed', 'Electric Callboy', 'Def Leppard', 'Slayer', 'Falling In Reverse', 'Seether', 'Rock Mafia', 'A Perfect Circle', 'Rockin Moroccin', 'Dream Theater', 'Limp Bizkit', 'Korn', 'Sepultura', 'Slipknot', 'Aerosmith', 'The Rocketman', 'Charlie Brown Jr.', 'Metal Nobre', 'rock', 'A$AP Rocky', 'Led Zeppelin', 'Deftones', 'Dayseeker', 'Metal', 'Scorpions', 'Architects', 'Bullet For My Valentine', 'Gojira', 'Green Day', 'Mötley Crüe', 'ENHYPEN', 'Parkway Drive', 'Brothers of Metal', 'Radiohead', 'Nine Inch Nails', "Guns N' Roses", 'Ozzy Osbourne', 'Breaking Benjamin', 'Disturbed', 'Elton John', 'The Offspring', 'Tiago Bettencourt', 'Bob Marley & The Wailers', 'Rockit Music', 'Spiritbox', 'Motionless In White', 'Arctic Monkeys', 'Coldplay', 'Oasis', 'Extreme', 'Imagine Dragons', 'Type O Negative', 'Thousand Foot Krutch', 'ROCK', 'System Of A Down', 'BLUNDER', 'Incubus', 'Metal Church', 'Buba Espinho', 'OneRepublic', 'Stray Kids', 'Queen', 'I Prevail', 'Billy Joel', 'Iron Maiden', 'Audioslave', 'Tame Impala', 'The Cranberries', 'The Goo Goo Dolls', 'Rock', 'Bring Me The Horizon', 'XXXTENTACION', 'Papa Roach', 'Metalocalypse: Dethklok', 'Megadeth', 'The Rolling Stones', 'Chappell Roan', 'Within Temptation', 'Lamb of God', 'ÁTOA', 'Stone Sour', 'Drowning Pool', 'Edi Rock', 'Rockout Danny', 'Rock Danger', 'Nirvana', 'Sabaton', 'Dire Straits', 'R.E.M.', 'Bryan Adams', 'Bon Jovi', 'HIM', 'Shinedown', 'Lorien Testard', 'Rockwell', 'Jay Rock', 'Five Finger Death Punch', 'The Cure', 'Faith No More', 'Guano Apes', 'Fleetwood Mac', 'Volbeat', 'Metal Sanctuary', 'Keane', 'Linkin Park', 'Phil Collins', 'Muse', 'Tom Odell', 'Nickelback', 'Tara Perdida', 'AC/DC', 'Poppy', 'Twenty One Pilots', 'Red Hot Chili Peppers', 'TOOL', 'Ghost', 'KISS', 'Rage Against The Machine', 'Skillet', 'Bad Omens', 'Black Sabbath', 'Europe', 'Rocket FX', 'The Police', 'Rammstein', 'Hoobastank', 'Rockywhereyoubeen', 'Sting', 'David Bowie', 'Eagles Of Death Metal', 'Three Days Grace', 'Metalite', 'The Strokes', 'Pink Floyd', 'BABYMETAL', 'D.A.M.A', 'ONE OK ROCK', 'Pantera', 'Maroon 5', 'The Beatles', 'Kings of Leon', 'Pearl Jam', 'PnB Rock', 'Pedro Abrunhosa', 'Diogo Piçarra', 'Metallica', 'Avenged Sevenfold', 'U2', 'The Killers', 'Evanescence', 'Godsmack', 'Staind', 'Kid Rock', 'Rockabye Baby!', 'Sleep Token', 'Alice In Chains', 'Judas Priest', 'ROCKET', 'Marilyn Manson', 'Van Halen', 'Da Weasel', 'Nightwish', 'Motörhead', 'Metal Mastery', 'Whitesnake', 'Foo Fighters', 'Alter Bridge'}

# %%
start = time.time()
for genre in genres_list:
    
    OFFSET = 0
    page = 1
    
    url_genre = f'https://api.spotify.com/v1/search?q={genre}&type=artist&limit={LIMIT}&offset={OFFSET}'
    
    response = requests.get(url_genre, headers = headers)
    
    if response.status_code == 401:
        token = get_token(SPOTIFY_URL_TOKEN, payload, headers)
        
        headers = {
                    'Authorization': f'Bearer {token}'
        }
        
        response = response = requests.get(url_genre, headers = headers)

    records = response.json()
    
    items = records.get('artists', {}).get('items', [])
    
    print(f'Reading artists of {genre} genre: Page nº {page}')
    
    if not items:
        print(f'No artists found for {genre}!')
        next = None
        
    
    for item in items:
        artists.append(item['name'])
        artists_id.append(item['id'])
        
        
    next = records.get('artists', {}).get('next', None)
    
    while next:
        
        OFFSET += LIMIT 
        page += 1
        
        url_genre = f'https://api.spotify.com/v1/search?q={genre}&type=artist&limit={LIMIT}&offset={OFFSET}'
        
        response = requests.get(url_genre, headers = headers)
        
        if response.status_code == 401:
            token = get_token(SPOTIFY_URL_TOKEN, payload, headers)
        
            headers = {
                    'Authorization': f'Bearer {token}'
            }
        
        response = response = requests.get(url_genre, headers = headers)

        records = response.json()
        
        items = records.get('artists', {}).get('items', [])
    
        
        print(f'Reading artists of {genre} genre: Page nº {page}')
        
        if not items:
            print(f'No artists found for {genre}!')
            next = None
        
        for item in items:
            artists.append(item['name'])
            artists_id.append(item['id'])
        
        next = records.get('artists', {}).get('next', None)

end = time.time()
print(f"Tempo total: {end - start:.2f} s")
# Out:
# Reading artists of afrobeat genre: Page nº 1
# Reading artists of afrobeat genre: Page nº 2
# Reading artists of afrobeat genre: Page nº 3
# Reading artists of afrobeat genre: Page nº 4
# Reading artists of afrobeat genre: Page nº 5
# Reading artists of afrobeat genre: Page nº 6
# Reading artists of afrobeat genre: Page nº 7
# Reading artists of afrobeat genre: Page nº 8
# Reading artists of afrobeat genre: Page nº 9
# Reading artists of afrobeat genre: Page nº 10
# Reading artists of afrobeat genre: Page nº 11
# Reading artists of afrobeat genre: Page nº 12
# Reading artists of afrobeat genre: Page nº 13
# Reading artists of afrobeat genre: Page nº 14
# Reading artists of afrobeats genre: Page nº 1
# Reading artists of afrobeats genre: Page nº 2
# Reading artists of afrobeats genre: Page nº 3
# Reading artists of afrobeats genre: Page nº 4
# Reading artists of afrobeats genre: Page nº 5
# Reading artists of afrobeats genre: Page nº 6
# Reading artists of afrobeats genre: Page nº 7
# Reading artists of afrobeats genre: Page nº 8
# Reading artists of afrobeats genre: Page nº 9
# Reading artists of afrobeats genre: Page nº 10
# Reading artists of afrobeats genre: Page nº 11
# Reading artists of afrobeats genre: Page nº 12
# Reading artists of afrobeats genre: Page nº 13
# Reading artists of afrobeats genre: Page nº 14
# Reading artists of afrobeats genre: Page nº 15
# Reading artists of afrobeats genre: Page nº 16
# Reading artists of afrobeats genre: Page nº 17
# Reading artists of afropiano genre: Page nº 1
# Reading artists of afropiano genre: Page nº 2
# Reading artists of afropiano genre: Page nº 3
# Reading artists of afropiano genre: Page nº 4
# Reading artists of afropiano genre: Page nº 5
# Reading artists of afropiano genre: Page nº 6
# Reading artists of afropiano genre: Page nº 7
# Reading artists of afropiano genre: Page nº 8
# Reading artists of afropiano genre: Page nº 9
# Reading artists of afropiano genre: Page nº 10
# Reading artists of afropiano genre: Page nº 11
# Reading artists of afropiano genre: Page nº 12
# Reading artists of afropiano genre: Page nº 13
# Reading artists of afropiano genre: Page nº 14
# Reading artists of afropiano genre: Page nº 15
# Reading artists of afropiano genre: Page nº 16
# Reading artists of afropiano genre: Page nº 17
# Reading artists of afropop genre: Page nº 1
# Reading artists of afropop genre: Page nº 2
# Reading artists of afropop genre: Page nº 3
# Reading artists of afropop genre: Page nº 4
# Reading artists of afropop genre: Page nº 5
# Reading artists of afropop genre: Page nº 6
# Reading artists of afropop genre: Page nº 7
# Reading artists of afropop genre: Page nº 8
# Reading artists of afropop genre: Page nº 9
# Reading artists of west coast hip hop genre: Page nº 12
# Reading artists of west coast hip hop genre: Page nº 13
# Reading artists of west coast hip hop genre: Page nº 14
# Reading artists of west coast hip hop genre: Page nº 15
# Reading artists of west coast hip hop genre: Page nº 16
# Reading artists of west coast hip hop genre: Page nº 17
# Tempo total: 3546.24 s

# %%
unique_artists = set(artists)

# %%
print(unique_artists)
# Out:
# {'Nest', 'Joshua Redman Quartet', 'Slofi', 'Jend', 'Şebnem Ferah', 'HYDE', 'Synthex', 'BENNETT', 'Luta Livre', 'Funk Wav', 'Tanishk Bagchi', 'Julio Daviel Big Band Conducted by Cucco Pena', 'Malcolm McLaren', 'Art District', 'Hoàng Duyên', 'Lil Mabu', 'Calango Aceso', 'Jimmie Vaughan', 'Sidónio Pereira', 'Panic', 'Denzel Curry', 'Shannon & The Clams', 'Banks', 'Kubla', 'Arkaea', 'Sundazer', 'Calvin Harris', 'Lowen', 'Ngô Kiến Huy', 'ÉLLÀH', 'KBrosser', 'Tori Kelly', 'SaberZ', 'Lifelover', 'Lida', 'Inês Monstro', 'Mayvi', 'Jaqee', 'Techno Bangers', 'Shooter Jennings', 'Abby Sage', 'DJ DUDA', 'Diesel Boy', 'Duncán', 'Facading', 'Brandee Younger', 'Jochy', 'Mulatoh Prod', 'Stonehaven', 'Sam Morrison Band', 'Kanine', 'Carola', 'Jakblauz', 'DØM', 'PHCK', 'Lana Rosewood', 'Barré', 'Hoke', 'Tiggs Da Author', 'El Chombo', 'Stimulator Jones', 'ST. NIKLAS', 'Tommy Royale', 'Roberto Jordan', 'Pretty Sick', 'Piano in a Living Room', 'Mguns', 'Jay Rock', 'Pithman', 'Josh Turner', 'Anal Cunt', 'Kid Frost', 'Praviver Worship', 'Tori Amos', 'GANSO', 'Elbello', 'Jamelia', 'Nevermore', 'Jonathan Frost', '7apes', 'YMIR', 'loran', 'ARTHA SISTER', 'Fattú Djakité', 'Charley Crockett', 'Mausi', 'Felt', 'Jasmine Myra', 'Sure Is Pure', 'They Fall', 'VaporVice', 'UNDEAD CORPORATION DOUJIN WORKS', 'Com Truise', 'Trueblood', 'Tony Scott', 'Kenny Rogers', 'Anirudh Ravichander', 'Roberta Campos', 'Moyka', 'Ancient', 'Miguel Agostinho', 'Lushe', 'Hardstylerzz', 'Samsara', 'Gaby Music', 'Fantomel', 'Roger Miller', 'Karime', 'Heavenly Lullaby', 'Soundz', 'Serani', 'Skatune Network', 'Corey Stapleton', "Vortek's", 'Jaylon', 'MC Pipokinha', 'Ellroy', 'MxPx', 'New PANTY & STOCKING with GARTERBELT', 'Fi Barreto', 'Anthus', 'Lofi MMMO', 'Nihility', 'XTC.', 'Luca-Dante Spadafora', 'Nils Frahm', 'King Tee', 'Alex Hosking', 'Gandhabba', 'Doc Severinsen', 'Rogues Gallery', 'Bill Withers', 'Acito', 'farofinat beats', 'Pedro Pascual', 'Charlie Haden', 'Vlone975', 'Baleia Baleia Baleia', 'Skyforger', 'Emancipator', 'Mamas Gun', 'Sheka', 'Coast Contra', 'Spencer Sutherland', 'The Happy Mess', 'Afrika System', 'Young Thug', 'D33J', 'Mainstay', 'eddy0', '16BL', 'Jazza Mazza', 'xander.', 'Así Canta Jerez', 'John Luongo', 'Yuvan Shankar Raja', 'Stoney Stone', 'Kalafina', 'Ruben de Ronde', 'TIKE', 'Fabienne DelSol', 'Smokey Silhouettes', '憂鬱', 'Frank Ekwa', 'Alex Pardos', 'Irmãs de Pau', 'Grupo Arte Final', 'LMR Records', 'JdM', 'Don Diablo', 'Visco', 'Artur', 'DEPARTURE', 'Slears', 'Edson & Hudson', 'Pagode do Vini', 'Full House Brew Crew', 'Dj Afro Gago', 'Lil Peep', 'j^p^n', 'F4ST', 'Vertigoaway', 'Artister av barnesanger og barnemusikk', 'Omar Courtz', 'Mr. Oizo', 'Falling Leaves', 'Redferrin', 'Max Diaz', 'Goblin Cock', 'Sam Morrison and Turn The Page', 'Dubox', 'Lytra', 'toe', 'Bryan Martin', 'La Chanson Noire', 'Bryartz', 'Ashley Wallbridge', 'Yellow Claw', 'Nero', 'Borislav Slavov', 'Aspect Juni', 'Mammoth', 'ゴールドシップ (CV. 上田 瞳)', 'Axel Thesleff', 'Palak Muchhal', 'Heriot', 'Capital da Bulgária', 'syudou', 'Luzon', 'Das Mörtal', 'BEAT', 'Like Moths To Flames', 'James Moody', 'Pete Philly', 'Ceehle', 'Dosh', 'Brandão85', 'C.W. Stoneking', 'Rellick', 'Patches', 'Tribruto', 'David Buckley', 'Rubí', 'ARTØRYA', 'Martes Fiore', 'Hindley Street Country Club', 'T.K. Soul', 'Riosse', 'Bryan Andrews', 'Confetti', 'Heart Attack', 'Malu', 'Skeme', 'Jazze Pha', 'Maikel Delacalle', 'Okay Kaya', 'Vijay Yesudas', 'B.B. King', 'Willie Nelson', 'Lucie Cravero', 'Paolo', 'Franz Liszt', 'Seals and Crofts', 'Deuce', 'AiMusicByTobias', 'Raggarea Sound', 'Tones On Tail', 'CABAL', 'Mudhoney', 'Gonçalo Pratas', 'Pagode do Meu Agrado', 'Larry Campbell', 'YA SIN', 'Steve Harley', 'wBoy', 'DSK Family', 'Latitudes', 'Varials', 'Chance Peña', 'AnimeVivi', 'Nós Dois', 'Stéphane Pompougnac', 'Ttheuz1n', 'Lofi Arcade', 'Execute', 'Luther Ingram', 'Swim Mountain', 'JazzWoman', "Bear's Den", 'Kirk Casey', 'Артем Кей', 'Drainers', 'David Marley', 'Familiar Folk', "Limsa d'Aulnay", 'Dominguinhos Do Estacio ...

# %%
print(genres)
# Out:
# ['classic rock', 'rock', 'glam rock']

# %%
genres_trance = ['trance', 'psytrance', 'progressive trance']
artistas_trance = []
artistas_trance_id = []

# %%
start = time.time()
for genre in genre_metal:
    
    OFFSET = 0
    page = 1
    
    url_genre = f'https://api.spotify.com/v1/search?q={genre}&type=artist&limit={LIMIT}&offset={OFFSET}'
    
    response = requests.get(url_genre, headers = headers)
    
    if response.status_code == 401:
        token = get_token(SPOTIFY_URL_TOKEN, payload, headers)
        
        headers = {
                    'Authorization': f'Bearer {token}'
        }
        
        response = response = requests.get(url_genre, headers = headers)

    records = response.json()
    
    items = records.get('artists', {}).get('items', [])
    
    print(f'Reading artists of {genre} genre: Page nº {page}')
    
    if not items:
        print(f'No artists found for {genre}!')
        next = None
        
    
    for item in items:
        artists_metal.append(item['name'])
        artists_metal_id.append(item['id'])
        
        
    next = records.get('artists', {}).get('next', None)
    
    while next:
        
        OFFSET += LIMIT 
        page += 1
        
        url_genre = f'https://api.spotify.com/v1/search?q={genre}&type=artist&limit={LIMIT}&offset={OFFSET}'
        
        response = requests.get(url_genre, headers = headers)
        
        if response.status_code == 401:
            token = get_token(SPOTIFY_URL_TOKEN, payload, headers)
        
            headers = {
                    'Authorization': f'Bearer {token}'
            }
        
        response = response = requests.get(url_genre, headers = headers)

        records = response.json()
        
        items = records.get('artists', {}).get('items', [])
    
        
        print(f'Reading artists of {genre} genre: Page nº {page}')
        
        if not items:
            print(f'No artists found for {genre}!')
            next = None
        
        for item in items:
            artists_metal.append(item['name'])
            artists_metal_id.append(item['id'])
        
        next = records.get('artists', {}).get('next', None)

end = time.time()
print(f"Tempo total: {end - start:.2f} s")
# Out:
# Reading artists of metal genre: Page nº 1
# Reading artists of metal genre: Page nº 2
# Reading artists of rock genre: Page nº 1
# Reading artists of rock genre: Page nº 2
# Tempo total: 12.31 s

# %%
set_trance = set(artistas_trance)

# %%
print(set_trance)
# Out:
# {'Claudinho Brasil', 'Prana', 'Cloud7', 'Shanti', 'Mirror World', 'Technical Hitch', 'Jeremy', 'Infected Mushroom', 'Alien Trancesistor', 'Pedro Sena', 'Belik Boom', 'WHITENO1SE', 'Tim Goldn', 'Jerro', 'Funk Tribu', 'Mark Sixma', 'AVAO', 'Jack Willard', 'Sharon Den Adel', 'Wrecked Machines', 'Crazy Box', 'Space Cat', 'Nort', 'Aria Seraphinas', 'Marieme', 'Kaskade', 'HACOON', 'Symphonix', 'Plumb', 'Phanatic', 'MØØNE', 'Purple Shapes', 'Sam Bagira', 'SoundLift', 'Darude', 'Trip-Tamine', 'XiJaro & Pitch', 'Radikal Moodz', 'Openzone Bar', 'Niels Van Gogh', 'Dzp', 'Prilho', 'TRANCEMAN2000', 'Three Drives On A Vinyl', 'Lightforce', 'Faders', 'Sash!', 'Solence', 'Kasablanca', 'Flegma', 'BlackBounce', 'Guy Salama', 'Paul Oakenfold', 'Miguel Lima', 'Merkaba', 'Vini Vincii', 'Eden Shalev', 'Progress', 'Electric Universe', 'Rob Swire', 'Hi Profile', 'Raja Ram', 'Goa Gil', 'Cosmic Gate', 'Visua', 'Babalos', 'Sian Evans', 'OMER DEEP', 'Killerwatts', 'Diana Miro', 'Haldolium', 'Gabriel & Dresden', 'Sere', 'Maria Nayler', 'Pettra', 'Sunlounger', 'MFG', 'Symbolic', 'Bizzare Tribe', 'Binary Finary', 'Aura Vortex', 'JAN DE VICE', 'Alienn', 'Trancemaster Krause', 'GAIA', 'Synthatic', 'E-Clip', 'Transient Disorder', 'Trance Farmers', 'Webra', 'Trace', 'Jacob', 'Anne Gudrun', 'Earthspace', 'Bamboo Forest', 'Psydewise', 'Danny Darko', 'DJ Gula K', 'Wonderful Lullabies', 'EA Games Soundtrack', 'Superluminal', 'Sick Addiction', 'Emma Hewitt', 'Deedrah', 'Hypnocoustics', 'Captain Hook', 'Trance Wax', 'O.T.B', 'Omnia', 'BLÜ EYES', 'Marsh', 'Enter Shikari', 'Bliss', 'Aquatica', 'ARTY', 'Vandeta', 'Sonic Waves', 'Overdrive (PSY)', 'Brigi', 'DEGO', 'Hang Massive', 'Sajanka', 'Sensi', 'WAIO', 'Alchimyst', 'Dj Jorge Sillvah', 'Krodax', 'Spectra Sonics', 'TRÅNCE', 'Chemical Noise', 'Gataka', 'Tommy Twinkle', 'Suria', 'Growling Machines', 'Cortex', 'Egorythmia', 'Rank 1', 'Voxell', 'Quim Das Remisturas', 'Matt Darey', 'Major7', 'Susie Ledge', 'Lost Tribe', 'Asking Alexandria', 'Mandala (UK)', 'Jerome Isma-Ae', 'Unlimited Psytrance', 'Render', 'Glender', 'Klur', 'Luis M', 'Onepix', 'Stonefox', 'Tripo', 'Blazy', 'Rowland Giles', 'Nadia Ali', 'Solarstone', 'NoFace', 'Dany G', 'Freedom Fighters', 'DJane Gaby', 'ATARA', 'Lipless', 'DJ Daddy Trance', 'Aurel (PSY)', 'Blind Channel', 'Suntree', 'Eytan Peled', 'CJ Stone', 'Andrew Rayel', 'Samsara', 'Outside The Universe', 'Sesto Sento', 'Tara Louise', 'Karime', 'Sasha', 'Perplex', 'Cosmic Flow', 'Talla 2XLC', 'Trance-lucence', 'Rafyx', 'ATB', 'Orko', 'We Came As Romans', 'Rui Da Silva', 'Trancesetters', 'Airwalk3r', 'MaRLo', 'Linney', 'Darwish', 'Ticon', 'Levi Heron', 'Kaikoo', 'Skazi', 'Gproject', 'Sousa', 'Coktel Molotov', '4 Strings', 'Innerzone', 'Alien Project', 'Vök', 'Talpa', 'ID', 'BBE', '4i20', 'Faithless', 'K FREQ', 'Vini Vici', 'Gandhabba', 'Future Species', 'Avalon', 'PANGEA', 'Gareth Emery', 'Alpha Portal', 'Hyperflow', 'Witchislav', 'Synesthetic', 'MR.BLACK', 'Outsiders', 'Reborn', 'Richard Durand', 'Sophie Ellis-Bextor', 'DJ Sammy', 'Davee', 'P.R.O.G.', 'Diego Miranda', 'A-Tech', 'Energy 52', 'Aquafeel', 'Above & Beyond', 'System Nipel', 'TrancEye', 'Professor Trance And The Energizers', 'T.I.T', 'Trancemission', 'KhoMha', 'Psychedelic Trance', 'Special M', '16BL', 'Dudiish', 'GMS', 'Transpose', 'Tropical Bleyage', 'Gouryella', 'Ruben de Ronde', 'Jana Luia', 'Trance Collective', 'Signum', 'Aly & Fila', 'Tristan', 'Psytrance', 'HRRTZ', 'EMKR', 'Alina Renae', 'LTN', 'Shanti People', 'Space Tribe', 'NONSENSE', 'Ephedrix', '4weekend', 'Moon', 'Arâm', 'Modus', 'Trance', 'Aykan Emir', 'LouP (BR)', 'Michael Mayo', 'Zen Mechanics', 'Two Birds', 'Labirinto', 'Frogg', 'Cosmonet', 'BackHaze', 'Tezla', 'Fluffkin', 'Oram (PT)', 'Reflekt', 'Zombie Nation', 'Zafrir', 'anamē', 'Tantra', 'Azzura', 'Lasmar', 'Ashley Wallbridge', 'Ritmo', '3LMT', 'Djantrix', 'Timmy Trumpet', 'Ajja', 'nilsix', 'Zoë Johnston', 'Cosmic illusion', 'Coexist', 'PHAE', 'DJ Feio', 'Ferry Corsten', 'Bizzare Contact', 'PROFF', 'Absolum', 'Sine', 'P ...

# %%
genre = 'samba'

# %%
url_genre = f'https://api.spotify.com/v1/search?q={genre}&type=artist'

# %%
#Com base num artista é possivel extrair os generos musicais e depois através do Spotify API search endpoint extrair outros artistas relacionados

# %%
print(genres_set)
# Out:
# {'k-pop', 'pagode', 'trip hop', 'blues', 'roots rock', 'synthwave', 'sertanejo', 'bossa nova', 'roots reggae', 'bebop', 'anime', 'synthpop', 'axé', 'pop punk', 'ska', 'rock', 'tech house', 'progressive rock', 'mpb', 'samba', 'free jazz', 'classic country', 'folk rock', 'forró tradicional', 'electro', 'outlaw country', 'hip hop', 'west coast hip hop', 'punk', 'drill', 'trance', 'sludge metal', 'vaporwave', 'edm', 'vocal jazz', 'folk', 'sertanejo universitário', 'country rock', 'power metal', 'hard rock', 'portuguese hip hop', 'indie rock', 'uk grime', 'latin jazz', 'trap latino', 'heavy metal', 'afropiano', 'alternative rock', 'lo-fi', 'gothic rock', 'arrocha', 'dubstep', 'drone metal', 'motown', 'forró', 'nu jazz', 'afropop', 'classic blues', 'speed metal', 'glam rock', 'death metal', 'jazz', 'black metal', 'techno', 'gothic metal', 'soundtrack', 'dub', 'j-r&b', 'jazz blues', 'progressive house', 'lo-fi hip hop', 'symphonic metal', 'swing music', 'rock and roll', 'uk drill', 'house', 'indie', 'electronic', 'flamenco', 'thrash metal', 'doom metal', 'funk pop', 'pagode baiano', 'hyperpop', 'downtempo', 'art pop', 'jazz fusion', 'folk metal', 'r&b', 'funk carioca', 'blues rock', 'darkwave', 'stoner metal', 'jazz rap', 'neo-psychedelic', 'cool jazz', 'reggaeton', 'classical piano', 'brazilian funk', 'afrobeat', 'funk', 'classic soul', 'classic rock', 'progressive trance', 'hard bop', 'latin', 'neo soul', 'soul blues', 'country', 'big band', 'fado', 'new wave', 'christmas', 'psychedelic rock', 'grindcore', 'chillwave', 'neoclassical', 'brazilian jazz', 'dancehall', 'reggae', 'groove metal', 'rap', 'rocksteady', 'soul', 'grunge', 'post-punk', 'metal', 'classical', 'drum and bass', 'ska punk', 'afrobeats', 'garage rock', 'ragga', 'urbano latino', 'electronica', 'afroswing', 'deathcore', 'brazilian pop', 'art rock', 'j-pop', 'lo-fi beats', 'singer-songwriter'}

# %%
#SPOTIFY_URL_TOKEN = 'https://accounts.spotify.com/api/token'
NOME_DO_ARTISTA_TRANCE = 'Tristan'
NOME_DO_ARTISTA_METAL = 'Metallica'
url = f'https://api.spotify.com/v1/search?q={new_artist}&type=artist'
url_genre = f'https://api.spotify.com/v1/search?q={GENRE_METAL}&type=artist'

# %%
payload = {

    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'grant_type': 'client_credentials'
}

headers = {

    'Content-type': 'application/x-www-form-urlencoded'
}

# %%
response = requests.post(SPOTIFY_URL_TOKEN, payload, headers)
print(response.json())
# Out:
# {'access_token': 'BQC8n0rHT2vxgNCXpwJKAJTDl07Uz_wIbqlcAuRjKVyp5n2swuZQZ6zVD350LBrG0MRnrfIJCZt_vy2SInFeRwQ7qbt8bii3_msUB1OffowRJN_g8dFIB1MjDQKxwchxBVkoLLV_Db8', 'token_type': 'Bearer', 'expires_in': 3600}

# %%
token = response.json()['access_token']
print(token)
headers_token = {
    'Authorization': f'Bearer {token}'
}
print(headers_token)
# Out:
# BQC8n0rHT2vxgNCXpwJKAJTDl07Uz_wIbqlcAuRjKVyp5n2swuZQZ6zVD350LBrG0MRnrfIJCZt_vy2SInFeRwQ7qbt8bii3_msUB1OffowRJN_g8dFIB1MjDQKxwchxBVkoLLV_Db8
# {'Authorization': 'Bearer BQC8n0rHT2vxgNCXpwJKAJTDl07Uz_wIbqlcAuRjKVyp5n2swuZQZ6zVD350LBrG0MRnrfIJCZt_vy2SInFeRwQ7qbt8bii3_msUB1OffowRJN_g8dFIB1MjDQKxwchxBVkoLLV_Db8'}

# %%
get_data = requests.get(url_genre, headers=headers)

records = get_data.json()

# %%
print(records['error'])
# Out:
# {'status': 401, 'message': 'The access token expired'}

# %%
print(records['artists'].keys())
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
print(records['artists']['next'])
# Out:
# None

# %%
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=genre%3A%22Dance%2FEletronic%22&type=artist', 'limit': 50, 'next': None, 'offset': 0, 'previous': None, 'total': 0, 'items': []}}

# %%
print(records['artists']['items'][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 print(records['artists']['items'][0])
#
# IndexError: list index out of range

# %%
for record in records:
    print(record)
# Out:
# artists

# %%
# Criar listas com os nomes dos artistas e em seguida pesquisar os dados de cada artista

# %%
url_genres = 'https://api.spotify.com/v1/browse/categories?country=BR&limit=10'

# %%
get_genres = requests.get(url_genres, headers = headers_token)

# %%
print(get_genres)
# Out:
# <Response [200]>

# %%
genres = get_genres.json()

# %%
print(genres['categories']['items'][0])
# Out:
# {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAt0tbjZptfcdMSKl3', 'id': '0JQ5DAt0tbjZptfcdMSKl3', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/images/728ed47fc1674feb95f7ac20236eb6d7.jpeg', 'width': 274}], 'name': 'Made For You'}

# %%
eee = requests.get(genres['categories']['items'][10]['href'], headers = headers_token)

# %%
ee_ = eee.json()

# %%
print(ee_)
# Out:
# {'href': 'https://api.spotify.com/v1/browse/categories/0JQ5DAqbMKFCkm2Enfbj7Y', 'id': '0JQ5DAqbMKFCkm2Enfbj7Y', 'icons': [{'height': 274, 'url': 'https://t.scdn.co/images/b307e822d6174e8cabe391da8196d70e.jpeg', 'width': 274}], 'name': 'Brazilian Funk'}
